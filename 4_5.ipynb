# %%
import pandas as pd

# %%
faults = pd.read_csv('./data/J1939Faults.csv', low_memory = False)

# %%
service_location1 = faults[(faults["Latitude"] == 36.066666) & (faults["Longitude"] == -86.434722)]

service_location2 = faults[(faults["Latitude"] == 35.588333) & (faults["Longitude"] == -86.443888)]

service_location3 = faults[(faults["Latitude"] == 36.1950) & (faults["Longitude"] ==  -83.174722 )]

services_locations = pd.concat([service_location1, service_location2, service_location3])

faults_cleaned = faults.drop(services_locations.index)

# %%
pd.read_csv('./data/VehicleDiagnosticOnboardData.csv')
# Out:
#                 Id                      Name        Value  FaultId
# 0                1                 IgnStatus        False        1
# 1                2         EngineOilPressure            0        1
# 2                3      EngineOilTemperature     96.74375        1
# 3                4        TurboBoostPressure            0        1
# 4                5                EngineLoad           11        1
# ...            ...                       ...          ...      ...
# 12821621  12864020  EngineCoolantTemperature        181.4  1248457
# 12821622  12864021              ParkingBrake        False  1248457
# 12821623  12864022    SwitchedBatteryVoltage         14.1  1248457
# 12821624  12864023               DistanceLtd  28606.65625  1248457
# 12821625  12864024                LampStatus         1023  1248458
#
# [12821626 rows x 4 columns]

# %%
pd.read_excel('./data/Service Fault Codes_1_0_0_167.xlsx')
# Out:
# C:\Users\j0909\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 0                         Y                 111       167  Not Mapped
# 1                         Y                 112       167  Not Mapped
# 2                         Y                 113       167  Not Mapped
# 3                         Y                 114       167  Not Mapped
# 4                         Y                 115       167         190
# ...                     ...                 ...       ...         ...
# 7119                      Y                9996       167  Not Mapped
# 7120                      Y                9997       167  Not Mapped
# 7121                      Y                9998       167  Not Mapped
# 7122                      Y                9999       167  Not Mapped
# ...

# %%
pd.read_excel('./data/Vehicle_Make.xlsx') #not useful
# Out:
#      Truck Number  Year          Make              Serial
# 0             535  1996  PETERBILT     1XPCDR8XXVN431011
# 1             534  1996  PETERBILT     1XPCPR8X8VN431010
# 2             533  1996  PETERBILT     1XPCDR8X1VN431009
# 3             532  1996  PETERBILT     1XPCDR8XXVN431008
# 4             531  1996  PETERBILT     1XPCDR8X8VN431007
# ..            ...   ...           ...                  ...
# 195           713  2004  VOLVO         4V4NC9TG84N355473
# 196           714  2004  VOLVO         4V4NC9TGX4N355474
# 197           715  2004  VOLVO         4V4NC9TG14N355475
# 198           716  2004  VOLVO         4V4NC9TG34N355476
# 199           717  2004  VOLVO         4V4NC9TG54N355477
#
# [200 rows x 4 columns]

# %%
import re
equip = faults_cleaned.EquipmentID
regex= '^\w{6,}$'

match = ~equip.str.contains(regex)

# %%
equip[match]
# Out:
# 0          1439
# 1          1439
# 2          1369
# 3          1369
# 4          1674
#            ...
# 1187330    2282
# 1187331    1994
# 1187332    1850
# 1187333    2377
# 1187334    2377
# Name: EquipmentID, Length: 1184701, dtype: object

# %%
faults_cleaned = faults_cleaned[faults_cleaned['EquipmentID'].map(len) <= 5]

# %%
faults_cleaned
# Out:
#          RecordID     ESS_Id           EventTimeStamp  \
